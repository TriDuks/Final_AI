# %% [markdown]
# <a href="https://colab.research.google.com/github/TriDuks/Final_AI/blob/main/class_name.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **DATASETS**

# %%
Datasets: https://drive.google.com/drive/folders/1Q6bL80OTBk8W51HBF7H1cMoED-8G1WK8?usp=share_link
# Out:
#   File "<ipython-input-1-b09185354ace>", line 1
#     Datasets: https://drive.google.com/drive/folders/1Q6bL80OTBk8W51HBF7H1cMoED-8G1WK8?usp=share_link
#                                                      ^
# SyntaxError: invalid decimal literal

# %%
#importing libraries
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from keras.preprocessing.image import ImageDataGenerator
from keras.utils import to_categorical, load_img, img_to_array

# %% [markdown]
# # **Processing**

# %%
#Preprocessing để Training 
# Load ảnh, chia loại, định lại cỡ ảnh 30x40, rescale ảnh, chia dữ liệu và định dạng ảnh về binary
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   validation_split = 0.05,
                                   rotation_range = 20,         #Tăng cường dữ liệu 
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True,                                 
                                  )
#train_datagen = ImageDataGenerator(rescale = 1./255)
training_set = train_datagen.flow_from_directory('/content/drive/MyDrive/AI/1_FINAL/Training', 
                                                 target_size = (128,128), 
                                                 batch_size = 32, 
                                                 class_mode = 'categorical')
# Out:
# Found 796 images belonging to 7 classes.

# %%
# Load ảnh, chia loại, định lại cỡ ảnh 30x40, rescale ảnh và định dạng ảnh về binary
test_datagen = ImageDataGenerator(rescale = 1./255,
                                  validation_split = 0.05,
                                  rotation_range = 20,         #Tăng cường dữ liệu 
                                  shear_range = 0.2,
                                  zoom_range = 0.2,
                                  horizontal_flip = True
                                  )
test_set = test_datagen.flow_from_directory('/content/drive/MyDrive/AI/1_FINAL/Test', 
                                                
                                                 target_size = (128,128), 
                                                 batch_size = 32, 
                                                class_mode = 'categorical')
# Out:
# Found 63 images belonging to 7 classes.

# %%
training_set.class_indices
# Out:
# {'Bicycle': 0,
#  'Bus': 1,
#  'Car': 2,
#  'DriverBicycle': 3,
#  'DriverMotorbike': 4,
#  'Motor': 5,
#  'Truck': 6}

# %%
test_set.class_indices
# Out:
# {'Bicycle': 0,
#  'Bus': 1,
#  'Car': 2,
#  'DriverBicycle': 3,
#  'DriverMotorbike': 4,
#  'Motor': 5,
#  'Truck': 6}

# %%
len(training_set)
# Out:
# 26

# %%
len(test_set)
# Out:
# 3

# %% [markdown]
# # **TẠO MODEL BẰNG CNN**

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Flatten, Dropout, Conv2D, MaxPooling2D, Normalization
import keras.backend as K
from keras.layers import LeakyReLU
from keras.callbacks import EarlyStopping
from keras.utils import to_categorical
from keras.optimizers import Adam

# %%
# Tạo model
model = Sequential()
#Thêm lớp chuyển đổi
model.add(Conv2D(32,(3,3), activation='linear', input_shape=[128,128,3],padding='same')) 
#Pooling
model.add(MaxPooling2D(pool_size=(2,2) , padding = 'same'))
model.add(Dropout(0.1))

#Tích chập lớp thứ 2
model.add(Conv2D(64,(3,3), activation = 'linear',padding='same'))
model.add(MaxPooling2D(pool_size=(2,2) , padding = 'same'))
model.add(Dropout(0.1))

model.add(Conv2D(128,(3,3), activation = 'linear',padding='same'))
model.add(MaxPooling2D(pool_size=(2,2) , padding = 'same'))
model.add(Dropout(0.2))

#Làm phẳng
model.add(Flatten())
  # ANN Layer
#Connect

model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.4))

#Output
model.add(Dense(7, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 128, 128, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 64, 64, 32)       0
#  )
#
#  dropout (Dropout)           (None, 64, 64, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 64, 64, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 32, 32, 64)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 32, 32, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 16, 16, 128)      0
#  2D)
#
#  dropout_2 (Dropout)         (None, 16, 16, 128)       0
#
#  flatten (Flatten)           (None, 32768)             0
#
#  dense (Dense)               (None, 1024)              33555456
#
#  dropout_3 (Dropout)         (None, 1024)              0
#
#  dense_1 (Dense)             (None, 7)                 7175
#
# =================================================================
# Total params: 33,655,879
# Trainable params: 33,655,879
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Thiết lập thông số
from keras.optimizers import Adam
model.compile( loss = 'categorical_crossentropy', optimizer=Adam(), metrics = ['accuracy'])

# %%
# Huấn luyện
# fit the model
# Run the cell. It will take some time to execute
a = model.fit( training_set, validation_data=test_set, epochs=80, steps_per_epoch=len(training_set), 
                        validation_steps=len(test_set)
)
# Out:
# Epoch 1/80
# 25/25 [==============================] - 331s 13s/step - loss: 3.7493 - accuracy: 0.2412 - val_loss: 1.8727 - val_accuracy: 0.2857
# Epoch 2/80
# 25/25 [==============================] - 55s 2s/step - loss: 1.5337 - accuracy: 0.4397 - val_loss: 2.0704 - val_accuracy: 0.3333
# Epoch 3/80
# 25/25 [==============================] - 51s 2s/step - loss: 1.2914 - accuracy: 0.5440 - val_loss: 1.7664 - val_accuracy: 0.3968
# Epoch 4/80
# 25/25 [==============================] - 52s 2s/step - loss: 1.1144 - accuracy: 0.5905 - val_loss: 1.4523 - val_accuracy: 0.5556
# Epoch 5/80
# 25/25 [==============================] - 51s 2s/step - loss: 0.9837 - accuracy: 0.6307 - val_loss: 1.4044 - val_accuracy: 0.5556
# Epoch 6/80
# 25/25 [==============================] - 52s 2s/step - loss: 0.9546 - accuracy: 0.6570 - val_loss: 1.7475 - val_accuracy: 0.5238
# Epoch 7/80
# 25/25 [==============================] - 50s 2s/step - loss: 0.8481 - accuracy: 0.6834 - val_loss: 1.4829 - val_accuracy: 0.5714
# Epoch 8/80
# 25/25 [==============================] - 51s 2s/step - loss: 0.7374 - accuracy: 0.7337 - val_loss: 1.7000 - val_accuracy: 0.5714
# Epoch 9/80
# 25/25 [==============================] - 50s 2s/step - loss: 0.6965 - accuracy: 0.7500 - val_loss: 1.5085 - val_accuracy: 0.5873
# Epoch 10/80
# 25/25 [==============================] - 51s 2s/step - loss: 0.7110 - accuracy: 0.7299 - val_loss: 1.2191 - val_accuracy: 0.6032
# Epoch 11/80
# 25/25 [==============================] - 50s 2s/step - loss: 0.6626 - accuracy: 0.7475 - val_loss: 1.2337 - val_accuracy: 0.6032
# Epoch 12/80
# 25/25 [==============================] - 51s 2s/step - loss: 0.5887 - accuracy: 0.7915 - val_loss: 1.3443 - val_accuracy: 0.6667
# Epoch 13/80
# 25/25 [==============================] - 51s 2s/step - loss: 0.6125 - accuracy: 0.7814 - val_loss: 1.2319 - val_accuracy: 0.5873
# Epoch 14/80
# 25/25 [==============================] - 52s 2s/step - loss: 0.5816 - accuracy: 0.7839 - val_loss: 1.2974 - val_accuracy: 0.6190
# Epoch 15/80
# 25/25 [==============================] - 52s 2s/step - loss: 0.5805 - accuracy: 0.7927 - val_loss: 1.1813 - val_accuracy: 0.6190
# Epoch 16/80
# 25/25 [==============================] - 51s 2s/step - loss: 0.4881 - accuracy: 0.8204 - val_loss: 1.2041 - val_accuracy: 0.6984
# Epoch 17/80
# 25/25 [==============================] - 51s 2s/step - loss: 0.4713 - accuracy: 0.8216 - val_loss: 1.1394 - val_accuracy: 0.7302
# Epoch 18/80
# 25/25 [==============================] - 50s 2s/step - loss: 0.4231 - accuracy: 0.8580 - val_loss: 0.8430 - val_accuracy: 0.7937
# Epoch 19/80
# 25/25 [==============================] - 50s 2s/step - loss: 0.3944 - accuracy: 0.8530 - val_loss: 1.0428 - val_accuracy: 0.6667
# Epoch 20/80
# 25/25 [==============================] - 52s 2s/step - loss: 0.3274 - accuracy: 0.8844 - val_loss: 1.1685 - val_accuracy: 0.6825
# Epoch 21/80
# 25/25 [==============================] - 50s 2s/step - loss: 0.3778 - accuracy: 0.8693 - val_loss: 1.0270 - val_accuracy: 0.6984
# Epoch 22/80
# 25/25 [==============================] - 51s 2s/step - loss: 0.3317 - accuracy: 0.8894 - val_loss: 1.4120 - val_accuracy: 0.7460
# Epoch 23/80
# 25/25 [==============================] - 50s 2s/step - loss: 0.3794 - accuracy: 0.8681 - val_loss: 1.1366 - val_accuracy: 0.7143
# Epoch 24/80
# 25/25 [==============================] - 50s 2s/step - loss: 0.3319 - accuracy: 0.8957 - val_loss: 1.2186 - val_accuracy: 0.7302
# Epoch 25/80
# 25/25 [==============================] - 49s 2s/step - loss: 0.3352 - accuracy: 0.8819 - val_loss: 0.9738 - val_accuracy: 0.6984
# Epoch 26/80
# 25/25 [==============================] - 51s 2s/step - loss: 0.2789 - accuracy: 0.9008 - val_loss: 1.2287 - val_accuracy: 0.6667
# Epoch 27/80
# 25/25 [==============================] - 50s 2s/step - loss: 0.2844 - accuracy: 0.9020 - val_loss: 1.1340 - val_accuracy: 0.7937
# Epoch 28/80
# 25/25 [==============================] - 51s 2s/step - loss: 0.2383 - accuracy: 0.9070 - val_loss: 1.2216 - val_accuracy: 0.6508
# Epoch 29/80
# 25/25 [==============================] - 49s 2s/step - loss: 0.3263 - accuracy: 0.8970 - val_loss: 1.2217 - val_accuracy: 0.7460
# Epoch 30/80
# 25/25 [==============================] - 50s 2s/step - loss: 0.2530 - accuracy: 0.9183 - val_loss: 1.1560 - val_accuracy: 0.7619
# Epoch 31/80
# 25/25 [==============================] - 50s 2s/step - loss: 0.2300 - accuracy: 0.9133 - val_loss: 1.3133 - val_accuracy: 0.6825
# Epoch 32/80
# 25/25 [==============================] - 52s 2s/step - loss: 0.2085 - accuracy: 0.9146 - val_loss: 1.4474 - val_accuracy: 0.7460
# Epoch 33/80
# 25/25 [==============================] - 51s 2s/step - loss: 0.2029 - accuracy: 0.9309 - val_loss: 1.2273 - val_accuracy: 0.7143
# Epoch 34/80
# 25/25 [==============================] - 50s 2s/step - loss: 0.2257 - accuracy: 0.9183 - val_loss: 1.5000 - val_accuracy: 0.7460
# Epoch 35/80
# 25/25 [==============================] - 51s 2s/step - loss: 0.2212 - accuracy: 0.9133 - val_loss: 1.6702 - val_accuracy: 0.6508
# Epoch 36/80
# 25/25 [==============================] - 52s 2s/step - loss: 0.2431 - accuracy: 0.9209 - val_loss: 1.9014 - val_accuracy: 0.7302
# Epoch 37/80
# 25/25 [==============================] - 52s 2s/step - loss: 0.2761 - accuracy: 0.9095 - val_loss: 1.5129 - val_accuracy: 0.6825
# Epoch 38/80
# 25/25 [==============================] - 51s 2s/step - loss: 0.1807 - accuracy: 0.9435 - val_loss: 1.4308 - val_accuracy: 0.7302
# Epoch 39/80
# 25/25 [==============================] - 52s 2s/step - loss: 0.2003 - accuracy: 0.9359 - val_loss: 0.9812 - val_accuracy: 0.7460
# Epoch 40/80
# 25/25 [==============================] - 49s 2s/step - loss: 0.1724 - accuracy: 0.9397 - val_loss: 1.5149 - val_accuracy: 0.7460
# Epoch 41/80
# 25/25 [==============================] - 51s 2s/step - loss: 0.1896 - accuracy: 0.9347 - val_loss: 1.3392 - val_accuracy: 0.7460
# Epoch 42/80
# 25/25 [==============================] - 49s 2s/step - loss: 0.1550 - accuracy: 0.9359 - val_loss: 1.3801 - val_accuracy: 0.7302
# Epoch 43/80
# 25/25 [==============================] - 51s 2s/step - loss: 0.1800 - accuracy: 0.9523 - val_loss: 1.5891 - val_accuracy: 0.7302
# Epoch 44/80
# 25/25 [==============================] - 51s 2s/step - loss: 0.2162 - accuracy: 0.9322 - val_loss: 1.6129 - val_accuracy: 0.7619
# Epoch 45/80
# 25/25 [==============================] - 51s 2s/step - loss: 0.1958 - accuracy: 0.9334 - val_loss: 1.5283 - val_accuracy: 0.7143
# Epoch 46/80
# 25/25 [==============================] - 49s 2s/step - loss: 0.1517 - accuracy: 0.9422 - val_loss: 1.4468 - val_accuracy: 0.7460
# Epoch 47/80
# 25/25 [==============================] - 49s 2s/step - loss: 0.1529 - accuracy: 0.9435 - val_loss: 1.1706 - val_accuracy: 0.7778
# Epoch 48/80
# 25/25 [==============================] - 51s 2s/step - loss: 0.2236 - accuracy: 0.9234 - val_loss: 1.0724 - val_accuracy: 0.7460
# Epoch 49/80
# 25/25 [==============================] - 50s 2s/step - loss: 0.1921 - accuracy: 0.9410 - val_loss: 1.1937 - val_accuracy: 0.7778
# Epoch 50/80
# 25/25 [==============================] - 52s 2s/step - loss: 0.1336 - accuracy: 0.9510 - val_loss: 1.5637 - val_accuracy: 0.7302
# Epoch 51/80
# 25/25 [==============================] - 50s 2s/step - loss: 0.1271 - accuracy: 0.9485 - val_loss: 1.2935 - val_accuracy: 0.6984
# Epoch 52/80
# 25/25 [==============================] - 51s 2s/step - loss: 0.1861 - accuracy: 0.9397 - val_loss: 1.6863 - val_accuracy: 0.7302
# Epoch 53/80
# 25/25 [==============================] - 49s 2s/step - loss: 0.1483 - accuracy: 0.9497 - val_loss: 1.1809 - val_accuracy: 0.7302
# Epoch 54/80
# 25/25 [==============================] - 51s 2s/step - loss: 0.0950 - accuracy: 0.9585 - val_loss: 1.3695 - val_accuracy: 0.7937
# Epoch 55/80
# 25/25 [==============================] - 51s 2s/step - loss: 0.1218 - accuracy: 0.9598 - val_loss: 1.9134 - val_accuracy: 0.7302
# Epoch 56/80
# 25/25 [==============================] - 50s 2s/step - loss: 0.1182 - accuracy: 0.9724 - val_loss: 0.9910 - val_accuracy: 0.8095
# Epoch 57/80
# 25/25 [==============================] - 51s 2s/step - loss: 0.1084 - accuracy: 0.9585 - val_loss: 1.4872 - val_accuracy: 0.8413
# Epoch 58/80
# 25/25 [==============================] - 51s 2s/step - loss: 0.1505 - accuracy: 0.9523 - val_loss: 1.2795 - val_accuracy: 0.7460
# Epoch 59/80
# 25/25 [==============================] - 51s 2s/step - loss: 0.1707 - accuracy: 0.9510 - val_loss: 1.5504 - val_accuracy: 0.8095
# Epoch 60/80
# 25/25 [==============================] - 48s 2s/step - loss: 0.1380 - accuracy: 0.9510 - val_loss: 2.0293 - val_accuracy: 0.6825
# Epoch 61/80
# 25/25 [==============================] - 51s 2s/step - loss: 0.1330 - accuracy: 0.9510 - val_loss: 1.4282 - val_accuracy: 0.7619
# Epoch 62/80
# 25/25 [==============================] - 50s 2s/step - loss: 0.1226 - accuracy: 0.9560 - val_loss: 1.4808 - val_accuracy: 0.7143
# Epoch 63/80
# 25/25 [==============================] - 51s 2s/step - loss: 0.1618 - accuracy: 0.9497 - val_loss: 1.9351 - val_accuracy: 0.7460
# Epoch 64/80
# 25/25 [==============================] - 49s 2s/step - loss: 0.1342 - accuracy: 0.9535 - val_loss: 1.3046 - val_accuracy: 0.7937
# Epoch 65/80
# 25/25 [==============================] - 48s 2s/step - loss: 0.1820 - accuracy: 0.9435 - val_loss: 2.3772 - val_accuracy: 0.7143
# Epoch 66/80
# 25/25 [==============================] - 49s 2s/step - loss: 0.1817 - accuracy: 0.9384 - val_loss: 1.3720 - val_accuracy: 0.7302
# Epoch 67/80
# 25/25 [==============================] - 51s 2s/step - loss: 0.1702 - accuracy: 0.9472 - val_loss: 1.0685 - val_accuracy: 0.8095
# Epoch 68/80
# 25/25 [==============================] - 49s 2s/step - loss: 0.1929 - accuracy: 0.9435 - val_loss: 1.2128 - val_accuracy: 0.7302
# Epoch 69/80
# 25/25 [==============================] - 49s 2s/step - loss: 0.1433 - accuracy: 0.9523 - val_loss: 1.1515 - val_accuracy: 0.8095
# Epoch 70/80
# 25/25 [==============================] - 49s 2s/step - loss: 0.1528 - accuracy: 0.9523 - val_loss: 1.2571 - val_accuracy: 0.7619
# Epoch 71/80
# 25/25 [==============================] - 50s 2s/step - loss: 0.1149 - accuracy: 0.9611 - val_loss: 2.0952 - val_accuracy: 0.6984
# Epoch 72/80
# 25/25 [==============================] - 50s 2s/step - loss: 0.1418 - accuracy: 0.9598 - val_loss: 1.3250 - val_accuracy: 0.7143
# Epoch 73/80
# 25/25 [==============================] - 49s 2s/step - loss: 0.1010 - accuracy: 0.9648 - val_loss: 1.2198 - val_accuracy: 0.8095
# Epoch 74/80
# 25/25 [==============================] - 54s 2s/step - loss: 0.0954 - accuracy: 0.9686 - val_loss: 0.9227 - val_accuracy: 0.8254
# Epoch 75/80
# 25/25 [==============================] - 50s 2s/step - loss: 0.1229 - accuracy: 0.9698 - val_loss: 1.8214 - val_accuracy: 0.7302
# Epoch 76/80
# 25/25 [==============================] - 49s 2s/step - loss: 0.1433 - accuracy: 0.9523 - val_loss: 1.4798 - val_accuracy: 0.7460
# Epoch 77/80
# 25/25 [==============================] - 49s 2s/step - loss: 0.1448 - accuracy: 0.9472 - val_loss: 1.1916 - val_accuracy: 0.7143
# Epoch 78/80
# 25/25 [==============================] - 49s 2s/step - loss: 0.0799 - accuracy: 0.9698 - val_loss: 1.5339 - val_accuracy: 0.7937
# Epoch 79/80
# 25/25 [==============================] - 50s 2s/step - loss: 0.1601 - accuracy: 0.9535 - val_loss: 1.3868 - val_accuracy: 0.7778
# Epoch 80/80
# 25/25 [==============================] - 51s 2s/step - loss: 0.2469 - accuracy: 0.9259 - val_loss: 2.0548 - val_accuracy: 0.6667

# %%
# Model evaluation
test_loss, test_acc = model.evaluate(test_set, verbose=False)
print("Test loss:", test_loss)
print("Test accuracy:", test_acc)
# Out:
# Test loss: 2.422696352005005
# Test accuracy: 0.6507936716079712

# %%
y_pred = model.predict_generator(test_set)
y_pred_class = y_pred > 0.4
y_pred_class
# Out:
# <ipython-input-9-e38c81e243d6>:1: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   y_pred = model.predict_generator(test_set)
# array([[False, False,  True, False, False, False, False],
#        [False, False,  True, False, False, False, False],
#        [False, False,  True, False, False, False, False],
#        [False, False, False, False,  True, False, False],
#        [False,  True, False, False, False, False, False],
#        [False, False, False, False, False,  True, False],
#        [False, False,  True, False, False, False, False],
#        [False,  True, False, False, False, False, False],
#        [ True, False, False, False, False, False, False],
#        [False, False,  True, False, False, False, False],
#        [False, False, False, False, False, False,  True],
#        [False, False,  True, False, False, False, False],
#        [False, False, False, False, False, False,  True],
#        [ True, False, False, False, False, False, False],
#        [False,  True, False, False, False, False, False],
#        [False, False, False, False, False,  True, False],
#        [False, False, False, False, False, False,  True],
#        [False, False, False, False, False, False,  True],
#        [False, False,  True, False, False, False, False],
#        [ True, False, False, False, False, False, False],
#        [ True, False, False, False, False, False, False],
#        [False,  True, False, False, False, False, False],
#        [ True, False, False, False, False, False, False],
#        [ True, False, False, False, False, False, False],
#        [False, False, False, False, False,  True, False],
#        [False, False,  True, False, False, False, False],
#        [False,  True, False, False, False, False, False],
#        [False, False, False, False, False, False, False],
#        [False, False, False, False, False,  True, False],
#        [False, False,  True, False, False, False, False],
#        [ True, False, False, False, False, False, False],
#        [ True, False, False, False, False, False, False],
#        [False, False, False, False, False, False,  True],
#        [False, False, False, False, False,  True, False],
#        [False,  True, False, False, False, False, False],
#        [False, False,  True, False, False, False, False],
#        [False, False, False, False, False, False,  True],
#        [False,  True, False, False, False, False, False],
#        [False,  True, False, False, False, False, False],
#        [False, False, False, False, False,  True, False],
#        [False, False,  True, False, False, False, False],
#        [False, False, False, False, False,  True, False],
#        [False, False, False, False, False,  True, False],
#        [False,  True, False, False, False, False, False],
#        [ True, False, False, False, False, False, False],
#        [False, False,  True, False, False, False, False],
#        [False, False, False,  True, False, False, False],
#        [ True, False, False, False, False, False, False],
#        [False, False,  True, False, False, False,  True],
#        [False, False, False,  True, False, False, False],
#        [False, False, False, False, False, False,  True],
#        [False, False, False, False, False,  True, False],
#        [False, False, False, False, False,  True, False],
#        [ True, False, False, False, False, False, False],
#        [False, False, False, False, False, False,  True],
#        [ True, False, False, False, False, False, False],
#        [False, False, False, False, False, False,  True],
#        [False,  True, False, False, False, False, False],
#        [False, False, False, False, False, False,  True],
#        [ True, False, False, False, False, False, False],
#        [False, False, False, False, False, False,  True],
#        [ True, False, False, False, False, False, False],
#        [ True, False, False, False, False, False, False]])

# %%
training_set.class_indices
# Out:
# {'Bicycle': 0, 'Bus': 1, 'Car': 2, 'Motor': 3}

# %%
import matplotlib.pyplot as plt
# plot the loss
plt.plot(a.history['loss'], label='train loss')
plt.plot(a.history['val_loss'], label='val loss')
plt.legend()
plt.show()
plt.savefig('LossVal_loss')

# plot the accuracy
plt.plot(a.history['accuracy'], label='train acc')
plt.plot(a.history['val_accuracy'], label='val acc')
plt.legend()
plt.show()
plt.savefig('AccVal_acc')

# %%
# Lưu a h5 file
from tensorflow.keras.models import load_model

model.save('/content/drive/MyDrive/AI/1_FINAL/model_inception.h5')

# %%
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image
model=load_model('/content/drive/MyDrive/AI/1_FINAL/model_inception.h5')
model

# %% [markdown]
# # **CHẠY THỬ NGHIỆM**

# %%
import matplotlib.pyplot as plt
from keras.utils import to_categorical, load_img, img_to_array
img_data = load_img('/content/drive/MyDrive/AI/1_FINAL/Valid/Test1.jpg') #bạn Phi
img_data = img_to_array(img_data)
plt.imshow(img_data/255)

# %%
import numpy as np
from keras.preprocessing import image
while 1 :
 ch = input('Chọn' ' image : ')
 if (ch=='-'):
     break
 else:
   try: 
     test_image = load_img("/content/drive/MyDrive/AI/1_FINAL/Valid/{}.jpg".format(ch),
                             target_size=(128,128)) #Scale
     test_image = img_to_array(test_image)
     plt.imshow(test_image/255)
     test_image = np.expand_dims(test_image,axis=0)
     r = (model.predict(test_image) > 0.5).astype("int32")
     print(r)
     x=0
     c=0
     i=0
     while (i<6):
       if r[0][i]>=x:
         x=r[0][i]
         c=i
        
       i=i+1
       #Bicycle': 0, 'Bus': 1, 'Car': 2, 'Motor': 3
     if (x<=0 and c>=6) :
         c=6
     if c == 0:
       prediction = 'Bicycle'
     elif c == 1:
       prediction = 'Bus'
     elif c == 2:
       prediction = 'Car'
     elif c == 3:
       prediction = 'Motor'
     elif c == 4:
       prediction = 'Bicycle'
     elif c == 5:
       prediction = 'Motor'
     elif c == 6:
       prediction = 'Truck'

           
     print(prediction)
   except:
      print('Tên của hình ảnh không tồn tại '  )

# %% [markdown]
# # **CODE IN PYTHON**

# %%
import tkinter as tk
from tkinter import filedialog
from tkinter import *
from PIL import ImageTk, Image
import numpy as np
from keras.models import load_model
from keras.utils import img_to_array
model = load_model('model_inception (6).h5')

#initialise GUI
top=tk.Tk()
top.geometry('800x600')
top.title('Vehicle Classification')
top.configure(background='#FFFFFF')
label=Label(top,background='#FFFFFF', font=('arial',15,'bold'))
sign_image = Label(top)
def classify(file_path):
    global label_packed
    image = Image.open(file_path)
    image = image.resize((128,128))
    image = img_to_array(image)
    Test_image = np.expand_dims(image, axis=0)
    #pred = np.argmax(model.predict(image), axis=-1)
    result = (model.predict(Test_image) > 0.5).astype("int32")
    #result = np.argmax(model.predict(Test_image), axis=-1)
    print(result)
    x=0
    c=0
    i=0
    while (i<6):
        if result[0][i]>= x:
            x=result[0][i]
            c=i
        i=i+1
    if (x<=0 and c>=5) :
        c = 6
       #Bicycle': 0, 'Bus': 1, 'Car': 2, 'Motor': 3
    if c == 0:
        prediction = 'Bicycle'
    elif c == 1:
        prediction = 'Bus'
    elif c == 2:
        prediction = 'Car'
    elif c == 3:
        prediction = 'Bicycle'
    elif c == 4:
        prediction = 'Motorbike'
    elif c == 5:
        prediction = 'Motorbike'
    elif c == 6:
        prediction = 'Truck'
    label.configure(foreground='#B20000', text=prediction, font=('arial',24,'bold'))
def show_classify_button(file_path):
    classify_b=Button(top,text="Classify Image",
   command=lambda: classify(file_path),
   padx=12,pady=5)
    classify_b.configure(background='#364156', foreground='white',
font=('arial',13,'bold'))
    classify_b.place(relx=0.79,rely=0.46)
def upload_image():
    try:
        file_path=filedialog.askopenfilename()
        uploaded=Image.open(file_path)
        uploaded.thumbnail(((top.winfo_width()/2.25),
    (top.winfo_height()/2.25)))
        im=ImageTk.PhotoImage(uploaded)
        sign_image.configure(image=im)
        sign_image.image=im
        label.configure(text='')
        show_classify_button(file_path)
    except:
        pass
upload=Button(top,text="Upload an image",command=upload_image,padx=12,pady=5)
upload.configure(background='#364156', foreground='white',font=('arial',13,'bold'))
upload.pack(side=BOTTOM,pady=40)
sign_image.pack(side=BOTTOM,expand=True)
print(sign_image)

label.pack(side=BOTTOM,expand=True)
heading = Label(top, text="Vehicle Classification",pady=20, font=('arial',20,'bold'))
heading.configure(background='#FFFFFF',foreground='#B20000')
heading.pack()
top.mainloop()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-1-3a4f66efdc69> in <cell line: 8>()
#       6 from keras.models import load_model
#       7 from keras.utils import img_to_array
# ----> 8 model = load_model('model_inception (6).h5')
#       9
#      10 #initialise GUI
#
# /usr/local/lib/python3.10/dist-packages/keras/saving/saving_api.py in load_model(filepath, custom_objects, compile, safe_mode, **kwargs)
#     210
#     211     # Legacy case.
# --> 212     return legacy_sm_saving_lib.load_model(
#     213         filepath, custom_objects=custom_objects, compile=compile, **kwargs
#     214     )
#
# /usr/local/lib/python3.10/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/saving/legacy/save.py in load_model(filepath, custom_objects, compile, options)
#     228                     if isinstance(filepath_str, str):
#     229                         if not tf.io.gfile.exists(filepath_str):
# --> 230                             raise IOError(
#     231                                 f"No file or directory found at {filepath_str}"
#     232                             )
#
# OSError: No file or directory found at model_inception (6).h5
